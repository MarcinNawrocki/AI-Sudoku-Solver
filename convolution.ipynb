# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
import copy

# %%
tf.config.experimental_run_functions_eagerly(True)

# %%
df = pd.read_csv("sudoku.csv")

# %%
df.head()
# Out:
#                                              quizzes  \
# 0  0043002090050090010700600430060020871900074000...
# 1  0401000501070039605200080000000000170009068008...
# 2  6001203840084590720000060050002640300700800069...
# 3  4972000001004000050000160986203000403009000000...
# 4  0059103080094030600275001000300002010008200070...
#
#                                            solutions
# 0  8643712593258497619712658434361925871986574322...
# 1  3461792581875239645296483719658324174729168358...
# 2  6951273841384596727248369158512647392739815469...
# 3  4972583161864397252537164986293815473759641828...
# 4  4659123781894735623275681497386452919548216372...

# %%
number_of_samples = 100000
unsolved = df['quizzes'].iloc[:number_of_samples].values
solved = df['solutions'].iloc[:number_of_samples].values

# %%
X = []
y = []

# %%
for sudoku in unsolved:
    np_solved = np.array([int(x) for x in sudoku]).reshape(9,9,1)
    X.append(np_solved)
    
for sudoku in solved:
    np_unsolved = np.array([int(y) for y in sudoku]).reshape(81,1) - 1
    y.append(np_unsolved)

# %%
np_X = np.array(X)
np_X = np_X/9
np_X -= 0.5
np_y = np.array(y)

# %%
#del(X)
#del(y)
#del(solved)
#del(unsolved)

# %%
np_y.shape
# Out:
# (100000, 81, 1)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
#default test size = 75%
X_train, X_test, y_train, y_test = train_test_split(np_X, np_y, test_size=0.2)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Reshape, BatchNormalization, Activation, Input,Dropout
from tensorflow.keras.optimizers import Adam

# %%
input_shape = (9,9,1)
batch_size = 128

# %%
model = Sequential()

model.add(Conv2D(64, kernel_size=(3,3), activation='relu', padding='same', input_shape=input_shape))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, kernel_size=(1,1), activation='relu', padding='same'))

model.add(Flatten())
model.add(Dense(81*9))
model.add(Reshape((-1, 9)))
model.add(Activation('softmax'))

adam = Adam(lr=0.001)
model.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 9, 9, 64)          640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 9, 9, 64)          256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 9, 9, 64)          36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 9, 9, 64)          256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 128)         8320
# _________________________________________________________________
# flatten (Flatten)            (None, 10368)             0
# _________________________________________________________________
# dense (Dense)                (None, 729)               7559001
# _________________________________________________________________
# reshape (Reshape)            (None, None, 9)           0
# _________________________________________________________________
# activation (Activation)      (None, None, 9)           0
# =================================================================
# Total params: 7,605,401
# Trainable params: 7,605,145
# Non-trainable params: 256
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=2, restore_best_weights=True)

# %%
with tf.device('/GPU:0'):
    model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data = [X_test, y_test], callbacks = [early_stop])
# Out:
# Train on 80000 samples, validate on 20000 samples
# Epoch 1/10
# 80000/80000 [==============================] - 21s 266us/sample - loss: 1.3991 - accuracy: 0.4694 - val_loss: 1.4773 - val_accuracy: 0.4685
# Epoch 2/10
# 80000/80000 [==============================] - 22s 272us/sample - loss: 0.5309 - accuracy: 0.7861 - val_loss: 0.4803 - val_accuracy: 0.7967
# Epoch 3/10
# 80000/80000 [==============================] - 22s 279us/sample - loss: 0.4419 - accuracy: 0.8100 - val_loss: 0.4468 - val_accuracy: 0.8031
# Epoch 4/10
# 80000/80000 [==============================] - 21s 267us/sample - loss: 0.4022 - accuracy: 0.8234 - val_loss: 0.4360 - val_accuracy: 0.8046
# Epoch 5/10
# 80000/80000 [==============================] - 22s 274us/sample - loss: 0.3652 - accuracy: 0.8398 - val_loss: 0.4420 - val_accuracy: 0.8032
# Epoch 6/10
# 80000/80000 [==============================] - 21s 266us/sample - loss: 0.3249 - accuracy: 0.8599 - val_loss: 0.4612 - val_accuracy: 0.7996

# %%
model.save("conv_model1.h5")

# %%
def normalize(np_a):
    
    return (np_a/9)-0.5

# %%
def denormalize(np_a):
    
    return (np_a+0.5)*9

# %%
def solve_batch(np_boards, np_solved_boards, model):
    np_results = np.empty(np_boards.shape[0],dtype=np.bool_)
    for i in np.ndindex(np_boards.shape[:1]):
        solved = solve_human_approach(np_boards[i], model)
        np_results[i] = compare_sudoku(solved, (np_solved_boards[i]+1).reshape(9,9))
        print(f"Solved sudoku number: {i}")
    correct_boards = np_results.sum()
    return correct_boards

# %%
def solve_human_approach (np_sample_board, model): 
    
    #np_board = np.copy(np_sample_board)
    np_board = np.copy(np_sample_board)
    #get number of blank in sudoku board
    #blanks_count = 81 - np.count_nonzero(np_board)
    
    #for _ in range(blanks_count):
    while(1):
        np_board_4d = np_board.reshape((1,9,9,1))
        predictions = model.predict(np_board_4d)[0]
        predictions_int = np.argmax(predictions, axis=1).reshape((9,9))+1           #change range of digits from <0,8> to <1,9>
        propabilities = np.around(np.max(predictions, axis=1).reshape((9,9)), 2) 
                        
        #get position with the highest propability
        np_board = denormalize(np_board).reshape((9,9))
        zeros = (np_board == 0)
        if (zeros.sum() == 0):
            break
        blanks_indices = np.where(zeros)
        blanks_indices = np.array([(i,j) for i,j in zip(blanks_indices[0], blanks_indices[1])])
        position_to_fill = blanks_indices[propabilities[zeros].argmax()]
        #fill position with the highest propability
        value_to_fill = predictions_int[position_to_fill[0], position_to_fill[1]]
        
        np_board[position_to_fill[0], position_to_fill[1]] = value_to_fill
        np_board = normalize(np_board)
    return np_board

# %%
def compare_sudoku (np_sudoku1, np_sudoku2):
    #True/False array
    comparision = np_sudoku1 == np_sudoku2
    #print(np.count_nonzero(comparision))
    return comparision.all()

# %%
x = solve_batch(X_test[:500], y_test[:500], model)
x
# Out:
# Solved sudoku number: (0,)
# Solved sudoku number: (1,)
# Solved sudoku number: (2,)
# Solved sudoku number: (3,)
# Solved sudoku number: (4,)
# Solved sudoku number: (5,)
# Solved sudoku number: (6,)
# Solved sudoku number: (7,)
# Solved sudoku number: (8,)
# Solved sudoku number: (9,)
# Solved sudoku number: (10,)
# Solved sudoku number: (11,)
# Solved sudoku number: (12,)
# Solved sudoku number: (13,)
# Solved sudoku number: (14,)
# Solved sudoku number: (15,)
# Solved sudoku number: (16,)
# Solved sudoku number: (17,)
# Solved sudoku number: (18,)
# Solved sudoku number: (19,)
# Solved sudoku number: (20,)
# Solved sudoku number: (21,)
# Solved sudoku number: (22,)
# Solved sudoku number: (23,)
# Solved sudoku number: (24,)
# Solved sudoku number: (25,)
# Solved sudoku number: (26,)
# Solved sudoku number: (27,)
# Solved sudoku number: (28,)
# Solved sudoku number: (29,)
# Solved sudoku number: (30,)
# Solved sudoku number: (31,)
# Solved sudoku number: (32,)
# Solved sudoku number: (33,)
# Solved sudoku number: (34,)
# Solved sudoku number: (35,)
# Solved sudoku number: (36,)
# Solved sudoku number: (37,)
# Solved sudoku number: (38,)
# Solved sudoku number: (39,)
# Solved sudoku number: (40,)
# Solved sudoku number: (41,)
# Solved sudoku number: (42,)
# Solved sudoku number: (43,)
# Solved sudoku number: (44,)
# Solved sudoku number: (45,)
# Solved sudoku number: (46,)
# Solved sudoku number: (47,)
# Solved sudoku number: (48,)
# Solved sudoku number: (49,)
# Solved sudoku number: (50,)
# Solved sudoku number: (51,)
# Solved sudoku number: (52,)
# Solved sudoku number: (53,)
# Solved sudoku number: (54,)
# Solved sudoku number: (55,)
# Solved sudoku number: (56,)
# Solved sudoku number: (57,)
# Solved sudoku number: (58,)
# Solved sudoku number: (59,)
# Solved sudoku number: (60,)
# Solved sudoku number: (61,)
# Solved sudoku number: (62,)
# Solved sudoku number: (63,)
# Solved sudoku number: (64,)
# Solved sudoku number: (65,)
# Solved sudoku number: (66,)
# Solved sudoku number: (67,)
# Solved sudoku number: (68,)
# Solved sudoku number: (69,)
# Solved sudoku number: (70,)
# Solved sudoku number: (71,)
# Solved sudoku number: (72,)
# Solved sudoku number: (73,)
# Solved sudoku number: (74,)
# Solved sudoku number: (75,)
# Solved sudoku number: (76,)
# Solved sudoku number: (77,)
# Solved sudoku number: (78,)
# Solved sudoku number: (79,)
# Solved sudoku number: (80,)
# Solved sudoku number: (81,)
# Solved sudoku number: (82,)
# Solved sudoku number: (83,)
# Solved sudoku number: (84,)
# Solved sudoku number: (85,)
# Solved sudoku number: (86,)
# Solved sudoku number: (87,)
# Solved sudoku number: (88,)
# Solved sudoku number: (89,)
# Solved sudoku number: (90,)
# Solved sudoku number: (91,)
# Solved sudoku number: (92,)
# Solved sudoku number: (93,)
# Solved sudoku number: (94,)
# Solved sudoku number: (95,)
# Solved sudoku number: (96,)
# Solved sudoku number: (97,)
# Solved sudoku number: (98,)
# Solved sudoku number: (99,)
# Solved sudoku number: (100,)
# Solved sudoku number: (101,)
# Solved sudoku number: (102,)
# Solved sudoku number: (103,)
# Solved sudoku number: (104,)
# Solved sudoku number: (105,)
# Solved sudoku number: (106,)
# Solved sudoku number: (107,)
# Solved sudoku number: (108,)
# Solved sudoku number: (109,)
# Solved sudoku number: (110,)
# Solved sudoku number: (111,)
# Solved sudoku number: (112,)
# Solved sudoku number: (113,)
# Solved sudoku number: (114,)
# Solved sudoku number: (115,)
# Solved sudoku number: (116,)
# Solved sudoku number: (117,)
# Solved sudoku number: (118,)
# Solved sudoku number: (119,)
# Solved sudoku number: (120,)
# Solved sudoku number: (121,)
# Solved sudoku number: (122,)
# Solved sudoku number: (123,)
# Solved sudoku number: (124,)
# Solved sudoku number: (125,)
# Solved sudoku number: (126,)
# Solved sudoku number: (127,)
# Solved sudoku number: (128,)
# Solved sudoku number: (129,)
# Solved sudoku number: (130,)
# Solved sudoku number: (131,)
# Solved sudoku number: (132,)
# Solved sudoku number: (133,)
# Solved sudoku number: (134,)
# Solved sudoku number: (135,)
# Solved sudoku number: (136,)
# Solved sudoku number: (137,)
# Solved sudoku number: (138,)
# Solved sudoku number: (139,)
# Solved sudoku number: (140,)
# Solved sudoku number: (141,)
# Solved sudoku number: (142,)
# Solved sudoku number: (143,)
# Solved sudoku number: (144,)
# Solved sudoku number: (145,)
# Solved sudoku number: (146,)
# Solved sudoku number: (147,)
# Solved sudoku number: (148,)
# Solved sudoku number: (149,)
# Solved sudoku number: (150,)
# Solved sudoku number: (151,)
# Solved sudoku number: (152,)
# Solved sudoku number: (153,)
# Solved sudoku number: (154,)
# Solved sudoku number: (155,)
# Solved sudoku number: (156,)
# Solved sudoku number: (157,)
# Solved sudoku number: (158,)
# Solved sudoku number: (159,)
# Solved sudoku number: (160,)
# Solved sudoku number: (161,)
# Solved sudoku number: (162,)
# Solved sudoku number: (163,)
# Solved sudoku number: (164,)
# Solved sudoku number: (165,)
# Solved sudoku number: (166,)
# Solved sudoku number: (167,)
# Solved sudoku number: (168,)
# Solved sudoku number: (169,)
# Solved sudoku number: (170,)
# Solved sudoku number: (171,)
# Solved sudoku number: (172,)
# Solved sudoku number: (173,)
# Solved sudoku number: (174,)
# Solved sudoku number: (175,)
# Solved sudoku number: (176,)
# Solved sudoku number: (177,)
# Solved sudoku number: (178,)
# Solved sudoku number: (179,)
# Solved sudoku number: (180,)
# Solved sudoku number: (181,)
# Solved sudoku number: (182,)
# Solved sudoku number: (183,)
# Solved sudoku number: (184,)
# Solved sudoku number: (185,)
# Solved sudoku number: (186,)
# Solved sudoku number: (187,)
# Solved sudoku number: (188,)
# Solved sudoku number: (189,)
# Solved sudoku number: (190,)
# Solved sudoku number: (191,)
# Solved sudoku number: (192,)
# Solved sudoku number: (193,)
# Solved sudoku number: (194,)
# Solved sudoku number: (195,)
# Solved sudoku number: (196,)
# Solved sudoku number: (197,)
# Solved sudoku number: (198,)
# Solved sudoku number: (199,)
# Solved sudoku number: (200,)
# Solved sudoku number: (201,)
# Solved sudoku number: (202,)
# Solved sudoku number: (203,)
# Solved sudoku number: (204,)
# Solved sudoku number: (205,)
# Solved sudoku number: (206,)
# Solved sudoku number: (207,)
# Solved sudoku number: (208,)
# Solved sudoku number: (209,)
# Solved sudoku number: (210,)
# Solved sudoku number: (211,)
# Solved sudoku number: (212,)
# Solved sudoku number: (213,)
# Solved sudoku number: (214,)
# Solved sudoku number: (215,)
# Solved sudoku number: (216,)
# Solved sudoku number: (217,)
# Solved sudoku number: (218,)
# Solved sudoku number: (219,)
# Solved sudoku number: (220,)
# Solved sudoku number: (221,)
# Solved sudoku number: (222,)
# Solved sudoku number: (223,)
# Solved sudoku number: (224,)
# Solved sudoku number: (225,)
# Solved sudoku number: (226,)
# Solved sudoku number: (227,)
# Solved sudoku number: (228,)
# Solved sudoku number: (229,)
# Solved sudoku number: (230,)
# Solved sudoku number: (231,)
# Solved sudoku number: (232,)
# Solved sudoku number: (233,)
# Solved sudoku number: (234,)
# Solved sudoku number: (235,)
# Solved sudoku number: (236,)
# Solved sudoku number: (237,)
# Solved sudoku number: (238,)
# Solved sudoku number: (239,)
# Solved sudoku number: (240,)
# Solved sudoku number: (241,)
# Solved sudoku number: (242,)
# Solved sudoku number: (243,)
# Solved sudoku number: (244,)
# Solved sudoku number: (245,)
# Solved sudoku number: (246,)
# Solved sudoku number: (247,)
# Solved sudoku number: (248,)
# Solved sudoku number: (249,)
# Solved sudoku number: (250,)
# Solved sudoku number: (251,)
# Solved sudoku number: (252,)
# Solved sudoku number: (253,)
# Solved sudoku number: (254,)
# Solved sudoku number: (255,)
# Solved sudoku number: (256,)
# Solved sudoku number: (257,)
# Solved sudoku number: (258,)
# Solved sudoku number: (259,)
# Solved sudoku number: (260,)
# Solved sudoku number: (261,)
# Solved sudoku number: (262,)
# Solved sudoku number: (263,)
# Solved sudoku number: (264,)
# Solved sudoku number: (265,)
# Solved sudoku number: (266,)
# Solved sudoku number: (267,)
# Solved sudoku number: (268,)
# Solved sudoku number: (269,)
# Solved sudoku number: (270,)
# Solved sudoku number: (271,)
# Solved sudoku number: (272,)
# Solved sudoku number: (273,)
# Solved sudoku number: (274,)
# Solved sudoku number: (275,)
# Solved sudoku number: (276,)
# Solved sudoku number: (277,)
# Solved sudoku number: (278,)
# Solved sudoku number: (279,)
# Solved sudoku number: (280,)
# Solved sudoku number: (281,)
# Solved sudoku number: (282,)
# Solved sudoku number: (283,)
# Solved sudoku number: (284,)
# Solved sudoku number: (285,)
# Solved sudoku number: (286,)
# Solved sudoku number: (287,)
# Solved sudoku number: (288,)
# Solved sudoku number: (289,)
# Solved sudoku number: (290,)
# Solved sudoku number: (291,)
# Solved sudoku number: (292,)
# Solved sudoku number: (293,)
# Solved sudoku number: (294,)
# Solved sudoku number: (295,)
# Solved sudoku number: (296,)
# Solved sudoku number: (297,)
# Solved sudoku number: (298,)
# Solved sudoku number: (299,)
# Solved sudoku number: (300,)
# Solved sudoku number: (301,)
# Solved sudoku number: (302,)
# Solved sudoku number: (303,)
# Solved sudoku number: (304,)
# Solved sudoku number: (305,)
# Solved sudoku number: (306,)
# Solved sudoku number: (307,)
# Solved sudoku number: (308,)
# Solved sudoku number: (309,)
# Solved sudoku number: (310,)
# Solved sudoku number: (311,)
# Solved sudoku number: (312,)
# Solved sudoku number: (313,)
# Solved sudoku number: (314,)
# Solved sudoku number: (315,)
# Solved sudoku number: (316,)
# Solved sudoku number: (317,)
# Solved sudoku number: (318,)
# Solved sudoku number: (319,)
# Solved sudoku number: (320,)
# Solved sudoku number: (321,)
# Solved sudoku number: (322,)
# Solved sudoku number: (323,)
# Solved sudoku number: (324,)
# Solved sudoku number: (325,)
# Solved sudoku number: (326,)
# Solved sudoku number: (327,)
# Solved sudoku number: (328,)
# Solved sudoku number: (329,)
# Solved sudoku number: (330,)
# Solved sudoku number: (331,)
# Solved sudoku number: (332,)
# Solved sudoku number: (333,)
# Solved sudoku number: (334,)
# Solved sudoku number: (335,)
# Solved sudoku number: (336,)
# Solved sudoku number: (337,)
# Solved sudoku number: (338,)
# Solved sudoku number: (339,)
# Solved sudoku number: (340,)
# Solved sudoku number: (341,)
# Solved sudoku number: (342,)
# Solved sudoku number: (343,)
# Solved sudoku number: (344,)
# Solved sudoku number: (345,)
# Solved sudoku number: (346,)
# Solved sudoku number: (347,)
# Solved sudoku number: (348,)
# Solved sudoku number: (349,)
# Solved sudoku number: (350,)
# Solved sudoku number: (351,)
# Solved sudoku number: (352,)
# Solved sudoku number: (353,)
# Solved sudoku number: (354,)
# Solved sudoku number: (355,)
# Solved sudoku number: (356,)
# Solved sudoku number: (357,)
# Solved sudoku number: (358,)
# Solved sudoku number: (359,)
# Solved sudoku number: (360,)
# Solved sudoku number: (361,)
# Solved sudoku number: (362,)
# Solved sudoku number: (363,)
# Solved sudoku number: (364,)
# Solved sudoku number: (365,)
# Solved sudoku number: (366,)
# Solved sudoku number: (367,)
# Solved sudoku number: (368,)
# Solved sudoku number: (369,)
# Solved sudoku number: (370,)
# Solved sudoku number: (371,)
# Solved sudoku number: (372,)
# Solved sudoku number: (373,)
# Solved sudoku number: (374,)
# Solved sudoku number: (375,)
# Solved sudoku number: (376,)
# Solved sudoku number: (377,)
# Solved sudoku number: (378,)
# Solved sudoku number: (379,)
# Solved sudoku number: (380,)
# Solved sudoku number: (381,)
# Solved sudoku number: (382,)
# Solved sudoku number: (383,)
# Solved sudoku number: (384,)
# Solved sudoku number: (385,)
# Solved sudoku number: (386,)
# Solved sudoku number: (387,)
# Solved sudoku number: (388,)
# Solved sudoku number: (389,)
# Solved sudoku number: (390,)
# Solved sudoku number: (391,)
# Solved sudoku number: (392,)
# Solved sudoku number: (393,)
# Solved sudoku number: (394,)
# Solved sudoku number: (395,)
# Solved sudoku number: (396,)
# Solved sudoku number: (397,)
# Solved sudoku number: (398,)
# Solved sudoku number: (399,)
# Solved sudoku number: (400,)
# Solved sudoku number: (401,)
# Solved sudoku number: (402,)
# Solved sudoku number: (403,)
# Solved sudoku number: (404,)
# Solved sudoku number: (405,)
# Solved sudoku number: (406,)
# Solved sudoku number: (407,)
# Solved sudoku number: (408,)
# Solved sudoku number: (409,)
# Solved sudoku number: (410,)
# Solved sudoku number: (411,)
# Solved sudoku number: (412,)
# Solved sudoku number: (413,)
# Solved sudoku number: (414,)
# Solved sudoku number: (415,)
# Solved sudoku number: (416,)
# Solved sudoku number: (417,)
# Solved sudoku number: (418,)
# Solved sudoku number: (419,)
# Solved sudoku number: (420,)
# Solved sudoku number: (421,)
# Solved sudoku number: (422,)
# Solved sudoku number: (423,)
# Solved sudoku number: (424,)
# Solved sudoku number: (425,)
# Solved sudoku number: (426,)
# Solved sudoku number: (427,)
# Solved sudoku number: (428,)
# Solved sudoku number: (429,)
# Solved sudoku number: (430,)
# Solved sudoku number: (431,)
# Solved sudoku number: (432,)
# Solved sudoku number: (433,)
# Solved sudoku number: (434,)
# Solved sudoku number: (435,)
# Solved sudoku number: (436,)
# Solved sudoku number: (437,)
# Solved sudoku number: (438,)
# Solved sudoku number: (439,)
# Solved sudoku number: (440,)
# Solved sudoku number: (441,)
# Solved sudoku number: (442,)
# Solved sudoku number: (443,)
# Solved sudoku number: (444,)
# Solved sudoku number: (445,)
# Solved sudoku number: (446,)
# Solved sudoku number: (447,)
# Solved sudoku number: (448,)
# Solved sudoku number: (449,)
# Solved sudoku number: (450,)
# Solved sudoku number: (451,)
# Solved sudoku number: (452,)
# Solved sudoku number: (453,)
# Solved sudoku number: (454,)
# Solved sudoku number: (455,)
# Solved sudoku number: (456,)
# Solved sudoku number: (457,)
# Solved sudoku number: (458,)
# Solved sudoku number: (459,)
# Solved sudoku number: (460,)
# Solved sudoku number: (461,)
# Solved sudoku number: (462,)
# Solved sudoku number: (463,)
# Solved sudoku number: (464,)
# Solved sudoku number: (465,)
# Solved sudoku number: (466,)
# Solved sudoku number: (467,)
# Solved sudoku number: (468,)
# Solved sudoku number: (469,)
# Solved sudoku number: (470,)
# Solved sudoku number: (471,)
# Solved sudoku number: (472,)
# Solved sudoku number: (473,)
# Solved sudoku number: (474,)
# Solved sudoku number: (475,)
# Solved sudoku number: (476,)
# Solved sudoku number: (477,)
# Solved sudoku number: (478,)
# Solved sudoku number: (479,)
# Solved sudoku number: (480,)
# Solved sudoku number: (481,)
# Solved sudoku number: (482,)
# Solved sudoku number: (483,)
# Solved sudoku number: (484,)
# Solved sudoku number: (485,)
# Solved sudoku number: (486,)
# Solved sudoku number: (487,)
# Solved sudoku number: (488,)
# Solved sudoku number: (489,)
# Solved sudoku number: (490,)
# Solved sudoku number: (491,)
# Solved sudoku number: (492,)
# Solved sudoku number: (493,)
# Solved sudoku number: (494,)
# Solved sudoku number: (495,)
# Solved sudoku number: (496,)
# Solved sudoku number: (497,)
# Solved sudoku number: (498,)
# Solved sudoku number: (499,)
# 221

# %%
y_test[1].reshape(9,9)
# Out:
# array([[4, 1, 2, 8, 7, 5, 0, 6, 3],
#        [8, 3, 7, 0, 6, 4, 1, 2, 5],
#        [6, 5, 0, 1, 2, 3, 4, 7, 8],
#        [3, 8, 1, 2, 4, 0, 7, 5, 6],
#        [7, 0, 5, 6, 1, 8, 2, 3, 4],
#        [2, 4, 6, 3, 5, 7, 8, 0, 1],
#        [5, 2, 3, 7, 8, 1, 6, 4, 0],
#        [0, 7, 8, 4, 3, 6, 5, 1, 2],
#        [1, 6, 4, 5, 0, 2, 3, 8, 7]])
